# %% [raw]
# / 演算子による除算結果はfloatになる。
# 整数の除算結果を得るには // 演算子を使う。
# ※//はより小さい整数に丸める
# //の結果が正の場合は切り捨てに同じ
# //の結果が負の場合は0方向への切り捨てではないことに注意
# ※また、//の結果はintとは限らない
# 右辺または左辺がfloatの場合はfloatになる

# %%
1 / 2
# Out:
# 0.5

# %%
3 // 2
# Out:
# 1

# %%
-13 // 2
# Out:
# -7

# %%
type(1/1)
# Out:
# float

# %%
type(1//1)
# Out:
# int

# %%
type(1.0//1)
# Out:
# float

# %% [raw]
# 剰余の計算は % 演算子を使う。

# %%
3 % 2
# Out:
# 1

# %% [raw]
# べき乗の計算は ** 演算子を使う。

# %%
2 ** 3
# Out:
# 8
